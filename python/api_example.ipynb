# %%
import pandas as pd
import requests
import json

# %%
# here is an example where we query the data between two dates and set the request limit to 10,000 rows (max is 50,000 rows)
url = "https://data.cityofnewyork.us/resource/76xm-jjuj?$where=incident_datetime between '2015-01-10T00:00:00' and '2015-01-15T00:00:00'&$limit=10000"

# %%
token = open("api-token.txt","r")
key = token.read()

# %%
headers = {
    "X-App-Token": key
}

# %%
r = requests.get(url)

# %%
df = pd.DataFrame(json.loads(r.text))

# %%
df.head()
# Out:
#   cad_incident_id        incident_datetime initial_call_type  \
# 0       150100001  2015-01-10T00:00:38.000            SICPED
# 1       150100003  2015-01-10T00:01:00.000            DIFFBR
# 2       150100004  2015-01-10T00:01:06.000              DRUG
# 3       150100005  2015-01-10T00:02:05.000            GYNHEM
# 4       150100006  2015-01-10T00:02:34.000               EDP
#
#   initial_severity_level_code final_call_type final_severity_level_code  \
# 0                           4          SICPED                         4
# 1                           2          DIFFBR                         2
# 2                           4            DRUG                         4
# 3                           5          GYNHEM                         5
# 4                           7            DRUG                         4
#
#   first_assignment_datetime valid_dispatch_rspns_time_indc  \
# 0   2015-01-10T00:01:23.000                              Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cad_incident_id                 10000 non-null  object
#  1   incident_datetime               10000 non-null  object
#  2   initial_call_type               10000 non-null  object
#  3   initial_severity_level_code     10000 non-null  object
#  4   final_call_type                 10000 non-null  object
#  5   final_severity_level_code       10000 non-null  object
#  6   first_assignment_datetime       9884 non-null   object
#  7   valid_dispatch_rspns_time_indc  10000 non-null  object
#  8   dispatch_response_seconds_qy    10000 non-null  object
#  9   first_activation_datetime       9868 non-null   object
#  10  first_on_scene_datetime         9642 non-null   object
#  11  valid_incident_rspns_time_indc  10000 non-null  object
# ...
